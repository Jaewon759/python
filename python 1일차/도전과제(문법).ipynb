# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```다음 중 14 % 3의 계산 결과로 옳은 것을 고르세요```
#
# 1. 4
# 2. 4.6
# 3. 2
# 4. 1

# %%
print(14%3)
# Out:
# 2

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```계산식의 결과가 실수인 것을 모두 고르세요```
#
# 1. float(17//3)
# 2. int(10)-9
# 3. float11/2
# 4. float(10)-2

# %%
float(17//3)
# Out:
# 5.0

# %%
int(10)-9
# Out:
# 1

# %%
float11/2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float11/2
#
# NameError: name 'float11' is not defined

# %%
float(10)-2
# Out:
# 8.0

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```Python에서 "#"이 의마하는 것은 무엇인지 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 주석

# %% [markdown]
# ----

# %% [markdown]
# [문제4]<br><br>
# 거듭제곱을 올바르게 표현한 식을 골라주세요
#
# 1. 2 ^^ 3
# 2. 2 ** 3
# 3. 2 ^* 3
# 4. 2 ~~ 3

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2

# %% [markdown]
# ----

# %% [markdown]
# [문제5]<br><br>
# 몫과 나머지를 함께 구하기 위해 사용할 수 있는 표현을 골라주세요
#
# 1. //
# 2. divmod()
# 3. %
# 4. /

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2

# %% [markdown]
# ----

# %% [markdown]
# [문제6]<br><br>
# 파이썬에서 한 줄 주석을 표현하는 방법은 무엇인가요?
#
# 1. `//`
# 2. `<!-- -- >`
# 3. "#"
# 4. `/* */`

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3

# %% [markdown]
# ----

# %% [markdown]
# [문제7]<br><br>
# 다음 중 여러 줄 주석처럼 사용할 수 있는 표현은?
#
# 1. `# 주석1 \n # 주석2`
# 2. `/* 주석 */`
# 3. `""" 여러 줄 """`
# 4. `// 여러 줄`

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3

# %% [markdown]
# ----

# %% [markdown]
# [문제8]<br><br>
# 다음 중 print 함수의 올바른 사용 예는?
#
# 1. `print "Hello"`
# 2. `print(Hello)`
# 3. `print("Hello")`
# 4. `print{'Hello'}`

# %%
Print "Hello"
# Out:
#   Cell In[5], line 1
#     Print "Hello"
#           ^
# SyntaxError: invalid syntax

# %%
print(Hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(Hello)
#
# NameError: name 'Hello' is not defined

# %%
print("Hello")
# Out:
# Hello

# %%
print{'Hello'}
# Out:
#   Cell In[8], line 1
#     print{'Hello'}
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3

# %% [markdown]
# ----

# %% [markdown]
# [문제9]<br><br>
# 파이썬에서 들여쓰기(indentation)가 필요한 문법이 아닌 것은?
#
# 1. if 조건문
# 2. 함수 정의
# 3. 반복문
# 4. 변수 선언

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 4

# %% [markdown]
# ----

# %% [markdown]
# [문제10]<br><br>
# 다음 중 연산 결과가 정수(`int`)가 아닌 것은?
#
# 1. `10 // 3`
# 2. `int(5.7)`
# 3. `float(3)`
# 4. `7 % 2`

# %%
10 // 3
# Out:
# 3

# %%
int(5.7)
# Out:
# 5

# %%
float(3)
# Out:
# 3.0

# %%
7 % 2
# Out:
# 1

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3

# %% [markdown]
# ----

# %% [markdown]
# [문제11]<br><br>
# 다음 중 출력 결과가 1.5가 되는 코드를 고르세요.
#
# 1. `print(3 // 2)`
# 2. `print(3 / 2)`
# 3. `print(3 % 2)`
# 4. `print(int(3 / 2))`

# %%
print(3 // 2)
# Out:
# 1

# %%
print(3 / 2)
# Out:
# 1.5

# %%
print(3 % 2)
# Out:
# 1

# %%
print(int(3 / 2))
# Out:
# 1

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2

# %% [markdown]
# ----

# %% [markdown]
# [문제12]<br><br>
# 다음 중 올바르게 float 형으로 변환한 예는?
#
# 1. float(7)
# 2. float("3.14")
# 3. float("abc")
# 4. float(3+2)

# %%
float(7)
# Out:
# 7.0

# %%
float("3.14")
# Out:
# 3.14

# %%
float("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 float("abc")
#
# ValueError: could not convert string to float: 'abc'

# %%
float(3+2)
# Out:
# 5.0

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1

# %% [markdown]
# ----

# %% [markdown]
# [문제13]<br><br>
# divmod(17, 4)의 반환값은?
#
# 1. (4, 1)
# 2. (4, 2)
# 3. 4.25
# 4. 1

# %%
divmod(17,4)
# Out:
# (4, 1)

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1

# %% [markdown]
# ----

# %% [markdown]
# [문제14]<br><br>
# 다음 중 pow(2, 3)과 같은 결과를 내는 식은?
#
# 1. 2 * 3
# 2. 2 ** 3
# 3. 2 ^ 3
# 4. 2 // 3

# %% [markdown]
# <span style="color:red">답변</span>

# %%
pow(2,3)
# Out:
# 8

# %%
2 * 3
# Out:
# 6

# %%
2 ** 3
# Out:
# 8

# %%
2 ^ 3
# Out:
# 1

# %%
2 // 3
# Out:
# 0

# %% [markdown]
# 2

# %% [markdown]
# ----

# %% [markdown]
# [문제15]<br><br>
# 파이썬에서 코드를 블록 단위로 구분하는 기준은 무엇인가요?
#
# 1. 줄번호
# 2. 들여쓰기
# 3. 괄호 {}
# 4. 세미콜론 ;

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제16]<br><br></span>
# ```주로 작성 중인 코드의 끝을 알리는 기호로 사용되며 파이썬에서 한 줄에 작성된 서로 다른 코드를 구분 지을 때 사용할 수 있는 기호를 골라주세요```
#
# 1. ' , ' (쉼표)
# 2. ' + ' (더하기 기호)
# 3. ' ; ' (세미콜론)
# 4. ' / ' (슬래시)

# %% [markdown]
# <span style="color:red">답변</span> :

# %% [markdown]
# 3

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제17]<br><br></span>
# ```Python의 PEP 8은 무엇인지 설명하고 PEP 8의 핵심적인 규칙을 1개 이상을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# PEP 8은 파이썬 코드 작성 시 따라야 할 공식 스타일 가이드입니다. 코드의 가독성과 일관성을 높이기 위해 사용됩니다.
# 핵심 규칙으로는 “들여쓰기를 4칸의 공백으로 한다” 또는 “함수 이름은 소문자와 밑줄을 사용하는 snake_case로 작성한다” 등이 있습니다.
